# %%
pip install chunkipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 51.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 691.3/691.3 kB 70.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 57.9 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=af2e2d8fa65b9906be12a3ef941c71ad450873f19e1063b898a5c101eade2662
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain
# Out:
# ...
#   Using cached langchain-0.2.13-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached langchain_core-0.2.30-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached langsmith-0.1.99-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
# ...
# Using cached langchain-0.2.13-py3-none-any.whl (997 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.3 MB/s eta 0:00:00
# ...
# Using cached langchain_core-0.2.30-py3-none-any.whl (384 kB)
# Using cached langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.99-py3-none-any.whl (140 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 115.3 MB/s eta 0:00:00
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Load your text file
with open('mergedfile.txt', 'r') as file:
    text = file.read()

# %%
import openai
 
# Set your OpenAI API key
openai.api_key = 'sk-41cB3JsCiA6k-FeqCgyAnUsKOX2FfeKdCm8_yka6VXT3BlbkFJsutJLVcgpL4P6aT_vVu2cMUGJf9_gE4Oh_6vkt9XcA'


from openai import OpenAI
client = OpenAI(api_key=openai.api_key)

def get_embedding(text, model="text-embedding-3-small"):
   #text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding


# Function to chunk the document
def chunk_document(document, max_tokens=500):
    words = document.split()
    chunks = []
    current_chunk = []
    current_length = 0
 
    for word in words:
        current_chunk.append(word)
        current_length += len(word) + 1  # +1 for the space
        if current_length >= max_tokens:
            chunks.append(' '.join(current_chunk))
            current_chunk = []
            current_length = 0
 
    if current_chunk:  # Add the last chunk
        chunks.append(' '.join(current_chunk))
 
    return chunks


# Step 2: Create embeddings for each chunk
embeddings = []
for chunk in chunks:
    embedding = get_embedding(chunk, model="text-embedding-3-small")
    embeddings.append(embedding)

# Now 'embeddings' will contain the embeddings for each chunk


 
# Function to create embeddings for each chunk
# def create_embeddings(chunks, model="text-embedding-3-small"):
#     embeddings = []
#     for chunk in chunks:
#         response = openai.Embedding.create(input=chunk, model=model)
#         embeddings.append(response['data'][0]['embedding'])
#     return embeddings
 
# Example document
document = """
Your large document text goes here.
This can be multiple paragraphs long and will be split into chunks.
"""
 
# Step 1: Chunk the document
chunks = chunk_document(document)
 
# Step 2: Create embeddings for each chunk
#embeddings = create_embeddings(chunks)
 
# Now 'embeddings' will contain the embeddings for each chunk
print(embeddings)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 39
#      37 embeddings = []
#      38 for chunk in chunks:
# ---> 39     embedding = get_embedding(chunk, model="text-embedding-3-small")
#      40     embeddings.append(embedding)
#      42 # Now 'embeddings' will contain the embeddings for each chunk
#      43
#      44
#    (...)
#      53
#      54 # Example document
#
# Cell In[14], line 12, in get_embedding(text, model)
#      10 def get_embedding(text, model="text-embedding-3-small"):
#      11    #text = text.replace("\n", " ")
# ---> 12    return client.embeddings.create(input = [text], model=model).data[0].embedding
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/openai/resources/embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
# ...

# %%
pip install openai
# Out:
# ...
#   Using cached openai-1.40.6-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# ...
# Using cached openai-1.40.6-py3-none-any.whl (361 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
